# %% [markdown]
# # Starting to analyze the data of 2016
#
# We will now analyze the Biobj part of the data. This is a different class
#
#
# The core of this algo is to loop over every dimension possible and inside loop over all the different type of functions,  print the name of the function, its associated ERT at the time where it reaches the smallest target precision.

# %%
import cocopp
dsl = cocopp.load("bbob-biobj/2016/*")
# Out:
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/DEMO_Tusar_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\DEMO_Tusar_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/HMO-CMA-ES_Loshchilov_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\HMO-CMA-ES_Loshchilov_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/MAT-DIRECT_Al-Dujaili_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\MAT-DIRECT_Al-Dujaili_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/MAT-SMS_Al-Dujaili_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\MAT-SMS_Al-Dujaili_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/MO-DIRECT-HV-Rank_Wong_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\MO-DIRECT-HV-Rank_Wong_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/MO-DIRECT-ND_Wong_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\MO-DIRECT-ND_Wong_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/MO-DIRECT-Rank_Wong_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\MO-DIRECT-Rank_Wong_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/NSGA-II-MATLAB_Auger_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\NSGA-II-MATLAB_Auger_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/RANDOMSEARCH-100_Auger_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\RANDOMSEARCH-100_Auger_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/RANDOMSEARCH-4_Auger_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\RANDOMSEARCH-4_Auger_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/RANDOMSEARCH-5_Auger_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\RANDOMSEARCH-5_Auger_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/RM-MEDA_Auger_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\RM-MEDA_Auger_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/RS-100.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\RS-100.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/RS-4.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\RS-4.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/SMS-EMOA-DE_Auger_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\SMS-EMOA-DE_Auger_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/SMS-EMOA-PM_Auger_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\SMS-EMOA-PM_Auger_bbob-biobj.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-biobj/2016/UP-MO-CMA-ES_Krause_bbob-biobj.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\UP-MO-CMA-ES_Krause_bbob-biobj.tgz
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_DEMO_Tusar_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_HMO-CMA-ES_Loshchilov_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_MAT-DIRECT_Al-Dujaili_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_MAT-SMS_Al-Dujaili_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_MO-DIRECT-HV-Rank_Wong_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_MO-DIRECT-ND_Wong_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_MO-DIRECT-Rank_Wong_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_NSGA-II-MATLAB_Auger_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_RANDOMSEARCH-100_Auger_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_RANDOMSEARCH-4_Auger_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_RANDOMSEARCH-5_Auger_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_RM-MEDA_Auger_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_RS-100 ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_RS-4 ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_SMS-EMOA-DE_Auger_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_SMS-EMOA-PM_Auger_bbob-biobj ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-biobj\2016\.extracted_UP-MO-CMA-ES_Krause_bbob-biobj ...
#   Data consistent according to consistency_check() in pproc.DataSet

# %% [markdown]
# ### Determine what is the best algo for a target precision of 1e-08,
#
# This code will be looping over each dimension and each type of function.

# %%
import numpy as np

dd = dsl.dictByDimFunc()     # your grouped datasets
t = 1e-8                     # choose the target precision

best_by_df = {}              # (dim, fid) -> (best_alg, best_ert)

for dim in sorted(dd.keys()): 
    for fid in sorted(dd[dim].keys()):
        rows = []
        for ds in dd[dim][fid]:                 # each ds = one algorithm
            ert = float(ds.detERT([t])[0])      # ERT in #evals at target t
            rows.append((ds.algId, ert))  
        # ignore INF (not reached) when picking best
        finite = [(a, e) for (a, e) in rows if np.isfinite(e)] 
    
        if finite:
            best_alg, best_ert = min(finite, key=lambda x: x[1]) 
        else:
            best_alg, best_ert = None, np.inf
        best_by_df[(dim, fid)] = (best_alg, best_ert) 
        print(f"dim={dim:>2}, F{fid:>2} -> {best_alg}  (ERT={best_ert:.3g} @ {t})")
# Out:
# dim= 2, F 1 -> None  (ERT=inf @ 1e-08)
# dim= 2, F 2 -> None  (ERT=inf @ 1e-08)
# dim= 2, F 3 -> None  (ERT=inf @ 1e-08)
# dim= 2, F 4 -> None  (ERT=inf @ 1e-08)
# dim= 2, F 5 -> None  (ERT=inf @ 1e-08)
# dim= 2, F 6 -> None  (ERT=inf @ 1e-08)
# dim= 2, F 7 -> None  (ERT=inf @ 1e-08)
# dim= 2, F 8 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2e+07 @ 1e-08)
# dim= 2, F 9 -> None  (ERT=inf @ 1e-08)
# dim= 2, F10 -> None  (ERT=inf @ 1e-08)
# dim= 2, F11 -> None  (ERT=inf @ 1e-08)
# dim= 2, F12 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=3.55e+06 @ 1e-08)
# dim= 2, F13 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=8.16e+05 @ 1e-08)
# dim= 2, F14 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=9.11e+06 @ 1e-08)
# dim= 2, F15 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.96e+07 @ 1e-08)
# dim= 2, F16 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=5.12e+06 @ 1e-08)
# dim= 2, F17 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=3.96e+06 @ 1e-08)
# dim= 2, F18 -> RM-MEDA_Auger_bbob-biobj  (ERT=1.9e+06 @ 1e-08)
# dim= 2, F19 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=8.57e+06 @ 1e-08)
# dim= 2, F20 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.92e+07 @ 1e-08)
# dim= 2, F21 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=5.21e+06 @ 1e-08)
# dim= 2, F22 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.92e+07 @ 1e-08)
# dim= 2, F23 -> None  (ERT=inf @ 1e-08)
# dim= 2, F24 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.12e+07 @ 1e-08)
# dim= 2, F25 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.96e+07 @ 1e-08)
# dim= 2, F26 -> RM-MEDA_Auger_bbob-biobj  (ERT=1.84e+06 @ 1e-08)
# dim= 2, F27 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.15e+07 @ 1e-08)
# dim= 2, F28 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.02e+06 @ 1e-08)
# dim= 2, F29 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=6.16e+06 @ 1e-08)
# dim= 2, F30 -> None  (ERT=inf @ 1e-08)
# dim= 2, F31 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.99e+07 @ 1e-08)
# dim= 2, F32 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=9.71e+06 @ 1e-08)
# dim= 2, F33 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.82e+06 @ 1e-08)
# dim= 2, F34 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=3.6e+06 @ 1e-08)
# dim= 2, F35 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.97e+07 @ 1e-08)
# dim= 2, F36 -> None  (ERT=inf @ 1e-08)
# dim= 2, F37 -> None  (ERT=inf @ 1e-08)
# dim= 2, F38 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2e+07 @ 1e-08)
# dim= 2, F39 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.97e+07 @ 1e-08)
# dim= 2, F40 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.99e+07 @ 1e-08)
# dim= 2, F41 -> None  (ERT=inf @ 1e-08)
# dim= 2, F42 -> None  (ERT=inf @ 1e-08)
# dim= 2, F43 -> None  (ERT=inf @ 1e-08)
# dim= 2, F44 -> None  (ERT=inf @ 1e-08)
# dim= 2, F45 -> None  (ERT=inf @ 1e-08)
# dim= 2, F46 -> None  (ERT=inf @ 1e-08)
# dim= 2, F47 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=2.3e+07 @ 1e-08)
# dim= 2, F48 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=3.92e+06 @ 1e-08)
# dim= 2, F49 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=2.28e+07 @ 1e-08)
# dim= 2, F50 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=6.32e+06 @ 1e-08)
# dim= 2, F51 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.98e+07 @ 1e-08)
# dim= 2, F52 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.13e+07 @ 1e-08)
# dim= 2, F53 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=2.36e+07 @ 1e-08)
# dim= 2, F54 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=2.2e+07 @ 1e-08)
# dim= 2, F55 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 1 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 2 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 3 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 4 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 5 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 6 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 7 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 8 -> None  (ERT=inf @ 1e-08)
# dim= 3, F 9 -> None  (ERT=inf @ 1e-08)
# dim= 3, F10 -> None  (ERT=inf @ 1e-08)
# dim= 3, F11 -> None  (ERT=inf @ 1e-08)
# dim= 3, F12 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.73e+06 @ 1e-08)
# dim= 3, F13 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.72e+06 @ 1e-08)
# dim= 3, F14 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=9.45e+06 @ 1e-08)
# dim= 3, F15 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.98e+07 @ 1e-08)
# dim= 3, F16 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.64e+07 @ 1e-08)
# dim= 3, F17 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=3.51e+07 @ 1e-08)
# dim= 3, F18 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.87e+07 @ 1e-08)
# dim= 3, F19 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.12e+07 @ 1e-08)
# dim= 3, F20 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=8.24e+06 @ 1e-08)
# dim= 3, F21 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=6.19e+06 @ 1e-08)
# dim= 3, F22 -> None  (ERT=inf @ 1e-08)
# dim= 3, F23 -> None  (ERT=inf @ 1e-08)
# dim= 3, F24 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.67e+07 @ 1e-08)
# dim= 3, F25 -> None  (ERT=inf @ 1e-08)
# dim= 3, F26 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.65e+07 @ 1e-08)
# dim= 3, F27 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.76e+07 @ 1e-08)
# dim= 3, F28 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.91e+07 @ 1e-08)
# dim= 3, F29 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.96e+07 @ 1e-08)
# dim= 3, F30 -> None  (ERT=inf @ 1e-08)
# dim= 3, F31 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.12e+07 @ 1e-08)
# dim= 3, F32 -> None  (ERT=inf @ 1e-08)
# dim= 3, F33 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=7.84e+06 @ 1e-08)
# dim= 3, F34 -> None  (ERT=inf @ 1e-08)
# dim= 3, F35 -> None  (ERT=inf @ 1e-08)
# dim= 3, F36 -> None  (ERT=inf @ 1e-08)
# dim= 3, F37 -> None  (ERT=inf @ 1e-08)
# dim= 3, F38 -> None  (ERT=inf @ 1e-08)
# dim= 3, F39 -> None  (ERT=inf @ 1e-08)
# dim= 3, F40 -> None  (ERT=inf @ 1e-08)
# dim= 3, F41 -> None  (ERT=inf @ 1e-08)
# dim= 3, F42 -> None  (ERT=inf @ 1e-08)
# dim= 3, F43 -> None  (ERT=inf @ 1e-08)
# dim= 3, F44 -> None  (ERT=inf @ 1e-08)
# dim= 3, F45 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=3.46e+07 @ 1e-08)
# dim= 3, F46 -> None  (ERT=inf @ 1e-08)
# dim= 3, F47 -> None  (ERT=inf @ 1e-08)
# dim= 3, F48 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=3.34e+07 @ 1e-08)
# dim= 3, F49 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=3.48e+07 @ 1e-08)
# dim= 3, F50 -> None  (ERT=inf @ 1e-08)
# dim= 3, F51 -> None  (ERT=inf @ 1e-08)
# dim= 3, F52 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=3.48e+07 @ 1e-08)
# dim= 3, F53 -> RM-MEDA_Auger_bbob-biobj  (ERT=3e+06 @ 1e-08)
# dim= 3, F54 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=8.08e+06 @ 1e-08)
# dim= 3, F55 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 1 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 2 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 3 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 4 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 5 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 6 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 7 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 8 -> None  (ERT=inf @ 1e-08)
# dim= 5, F 9 -> None  (ERT=inf @ 1e-08)
# dim= 5, F10 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=5.88e+07 @ 1e-08)
# dim= 5, F11 -> None  (ERT=inf @ 1e-08)
# dim= 5, F12 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.9e+06 @ 1e-08)
# dim= 5, F13 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=4.05e+06 @ 1e-08)
# dim= 5, F14 -> None  (ERT=inf @ 1e-08)
# dim= 5, F15 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=4.99e+07 @ 1e-08)
# dim= 5, F16 -> None  (ERT=inf @ 1e-08)
# dim= 5, F17 -> None  (ERT=inf @ 1e-08)
# dim= 5, F18 -> None  (ERT=inf @ 1e-08)
# dim= 5, F19 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.52e+07 @ 1e-08)
# dim= 5, F20 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.44e+07 @ 1e-08)
# dim= 5, F21 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=7.28e+06 @ 1e-08)
# dim= 5, F22 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=4.99e+07 @ 1e-08)
# dim= 5, F23 -> None  (ERT=inf @ 1e-08)
# dim= 5, F24 -> None  (ERT=inf @ 1e-08)
# dim= 5, F25 -> None  (ERT=inf @ 1e-08)
# dim= 5, F26 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.27e+07 @ 1e-08)
# dim= 5, F27 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=2.26e+07 @ 1e-08)
# dim= 5, F28 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.61e+07 @ 1e-08)
# dim= 5, F29 -> None  (ERT=inf @ 1e-08)
# dim= 5, F30 -> None  (ERT=inf @ 1e-08)
# dim= 5, F31 -> None  (ERT=inf @ 1e-08)
# dim= 5, F32 -> None  (ERT=inf @ 1e-08)
# dim= 5, F33 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=5.55e+07 @ 1e-08)
# dim= 5, F34 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=5.69e+07 @ 1e-08)
# dim= 5, F35 -> None  (ERT=inf @ 1e-08)
# dim= 5, F36 -> None  (ERT=inf @ 1e-08)
# dim= 5, F37 -> None  (ERT=inf @ 1e-08)
# dim= 5, F38 -> None  (ERT=inf @ 1e-08)
# dim= 5, F39 -> None  (ERT=inf @ 1e-08)
# dim= 5, F40 -> None  (ERT=inf @ 1e-08)
# dim= 5, F41 -> None  (ERT=inf @ 1e-08)
# dim= 5, F42 -> None  (ERT=inf @ 1e-08)
# dim= 5, F43 -> None  (ERT=inf @ 1e-08)
# dim= 5, F44 -> None  (ERT=inf @ 1e-08)
# dim= 5, F45 -> None  (ERT=inf @ 1e-08)
# dim= 5, F46 -> None  (ERT=inf @ 1e-08)
# dim= 5, F47 -> None  (ERT=inf @ 1e-08)
# dim= 5, F48 -> None  (ERT=inf @ 1e-08)
# dim= 5, F49 -> None  (ERT=inf @ 1e-08)
# dim= 5, F50 -> None  (ERT=inf @ 1e-08)
# dim= 5, F51 -> None  (ERT=inf @ 1e-08)
# dim= 5, F52 -> None  (ERT=inf @ 1e-08)
# dim= 5, F53 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=2.59e+07 @ 1e-08)
# dim= 5, F54 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=5.74e+07 @ 1e-08)
# dim= 5, F55 -> None  (ERT=inf @ 1e-08)
# dim=10, F 1 -> None  (ERT=inf @ 1e-08)
# dim=10, F 2 -> None  (ERT=inf @ 1e-08)
# dim=10, F 3 -> None  (ERT=inf @ 1e-08)
# dim=10, F 4 -> None  (ERT=inf @ 1e-08)
# dim=10, F 5 -> None  (ERT=inf @ 1e-08)
# dim=10, F 6 -> None  (ERT=inf @ 1e-08)
# dim=10, F 7 -> None  (ERT=inf @ 1e-08)
# dim=10, F 8 -> None  (ERT=inf @ 1e-08)
# dim=10, F 9 -> None  (ERT=inf @ 1e-08)
# dim=10, F10 -> None  (ERT=inf @ 1e-08)
# dim=10, F11 -> None  (ERT=inf @ 1e-08)
# dim=10, F12 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.36e+07 @ 1e-08)
# dim=10, F13 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=4.84e+07 @ 1e-08)
# dim=10, F14 -> None  (ERT=inf @ 1e-08)
# dim=10, F15 -> None  (ERT=inf @ 1e-08)
# dim=10, F16 -> None  (ERT=inf @ 1e-08)
# dim=10, F17 -> None  (ERT=inf @ 1e-08)
# dim=10, F18 -> None  (ERT=inf @ 1e-08)
# dim=10, F19 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=9.92e+07 @ 1e-08)
# dim=10, F20 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=8.55e+06 @ 1e-08)
# dim=10, F21 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=4.94e+07 @ 1e-08)
# dim=10, F22 -> None  (ERT=inf @ 1e-08)
# dim=10, F23 -> None  (ERT=inf @ 1e-08)
# dim=10, F24 -> None  (ERT=inf @ 1e-08)
# dim=10, F25 -> None  (ERT=inf @ 1e-08)
# dim=10, F26 -> None  (ERT=inf @ 1e-08)
# dim=10, F27 -> HMO-CMA-ES_Loshchilov_bbob-biobj  (ERT=1.15e+08 @ 1e-08)
# dim=10, F28 -> None  (ERT=inf @ 1e-08)
# dim=10, F29 -> None  (ERT=inf @ 1e-08)
# dim=10, F30 -> None  (ERT=inf @ 1e-08)
# dim=10, F31 -> None  (ERT=inf @ 1e-08)
# dim=10, F32 -> None  (ERT=inf @ 1e-08)
# dim=10, F33 -> None  (ERT=inf @ 1e-08)
# dim=10, F34 -> None  (ERT=inf @ 1e-08)
# dim=10, F35 -> None  (ERT=inf @ 1e-08)
# dim=10, F36 -> None  (ERT=inf @ 1e-08)
# dim=10, F37 -> None  (ERT=inf @ 1e-08)
# dim=10, F38 -> None  (ERT=inf @ 1e-08)
# dim=10, F39 -> None  (ERT=inf @ 1e-08)
# dim=10, F40 -> None  (ERT=inf @ 1e-08)
# dim=10, F41 -> None  (ERT=inf @ 1e-08)
# dim=10, F42 -> None  (ERT=inf @ 1e-08)
# dim=10, F43 -> None  (ERT=inf @ 1e-08)
# dim=10, F44 -> None  (ERT=inf @ 1e-08)
# dim=10, F45 -> None  (ERT=inf @ 1e-08)
# dim=10, F46 -> None  (ERT=inf @ 1e-08)
# dim=10, F47 -> None  (ERT=inf @ 1e-08)
# dim=10, F48 -> None  (ERT=inf @ 1e-08)
# dim=10, F49 -> None  (ERT=inf @ 1e-08)
# dim=10, F50 -> None  (ERT=inf @ 1e-08)
# dim=10, F51 -> None  (ERT=inf @ 1e-08)
# dim=10, F52 -> None  (ERT=inf @ 1e-08)
# dim=10, F53 -> None  (ERT=inf @ 1e-08)
# dim=10, F54 -> None  (ERT=inf @ 1e-08)
# dim=10, F55 -> None  (ERT=inf @ 1e-08)
# dim=20, F 1 -> None  (ERT=inf @ 1e-08)
# dim=20, F 2 -> None  (ERT=inf @ 1e-08)
# dim=20, F 3 -> None  (ERT=inf @ 1e-08)
# dim=20, F 4 -> None  (ERT=inf @ 1e-08)
# dim=20, F 5 -> None  (ERT=inf @ 1e-08)
# dim=20, F 6 -> None  (ERT=inf @ 1e-08)
# dim=20, F 7 -> None  (ERT=inf @ 1e-08)
# dim=20, F 8 -> None  (ERT=inf @ 1e-08)
# dim=20, F 9 -> None  (ERT=inf @ 1e-08)
# dim=20, F10 -> None  (ERT=inf @ 1e-08)
# dim=20, F11 -> None  (ERT=inf @ 1e-08)
# dim=20, F12 -> UP-MO-CMA-ES_Krause_bbob-biobj  (ERT=1.99e+08 @ 1e-08)
# dim=20, F13 -> None  (ERT=inf @ 1e-08)
# dim=20, F14 -> None  (ERT=inf @ 1e-08)
# dim=20, F15 -> None  (ERT=inf @ 1e-08)
# dim=20, F16 -> None  (ERT=inf @ 1e-08)
# dim=20, F17 -> None  (ERT=inf @ 1e-08)
# dim=20, F18 -> None  (ERT=inf @ 1e-08)
# dim=20, F19 -> None  (ERT=inf @ 1e-08)
# dim=20, F20 -> None  (ERT=inf @ 1e-08)
# dim=20, F21 -> None  (ERT=inf @ 1e-08)
# dim=20, F22 -> None  (ERT=inf @ 1e-08)
# dim=20, F23 -> None  (ERT=inf @ 1e-08)
# dim=20, F24 -> None  (ERT=inf @ 1e-08)
# dim=20, F25 -> None  (ERT=inf @ 1e-08)
# dim=20, F26 -> None  (ERT=inf @ 1e-08)
# dim=20, F27 -> None  (ERT=inf @ 1e-08)
# dim=20, F28 -> None  (ERT=inf @ 1e-08)
# dim=20, F29 -> None  (ERT=inf @ 1e-08)
# dim=20, F30 -> None  (ERT=inf @ 1e-08)
# dim=20, F31 -> None  (ERT=inf @ 1e-08)
# dim=20, F32 -> None  (ERT=inf @ 1e-08)
# dim=20, F33 -> None  (ERT=inf @ 1e-08)
# dim=20, F34 -> None  (ERT=inf @ 1e-08)
# dim=20, F35 -> None  (ERT=inf @ 1e-08)
# dim=20, F36 -> None  (ERT=inf @ 1e-08)
# dim=20, F37 -> None  (ERT=inf @ 1e-08)
# dim=20, F38 -> None  (ERT=inf @ 1e-08)
# dim=20, F39 -> None  (ERT=inf @ 1e-08)
# dim=20, F40 -> None  (ERT=inf @ 1e-08)
# dim=20, F41 -> None  (ERT=inf @ 1e-08)
# dim=20, F42 -> None  (ERT=inf @ 1e-08)
# dim=20, F43 -> None  (ERT=inf @ 1e-08)
# dim=20, F44 -> None  (ERT=inf @ 1e-08)
# dim=20, F45 -> None  (ERT=inf @ 1e-08)
# dim=20, F46 -> None  (ERT=inf @ 1e-08)
# dim=20, F47 -> None  (ERT=inf @ 1e-08)
# dim=20, F48 -> None  (ERT=inf @ 1e-08)
# dim=20, F49 -> None  (ERT=inf @ 1e-08)
# dim=20, F50 -> None  (ERT=inf @ 1e-08)
# dim=20, F51 -> None  (ERT=inf @ 1e-08)
# dim=20, F52 -> None  (ERT=inf @ 1e-08)
# dim=20, F53 -> None  (ERT=inf @ 1e-08)
# dim=20, F54 -> None  (ERT=inf @ 1e-08)
# dim=20, F55 -> None  (ERT=inf @ 1e-08)
# dim=40, F 1 -> None  (ERT=inf @ 1e-08)
# dim=40, F 2 -> None  (ERT=inf @ 1e-08)
# dim=40, F 3 -> None  (ERT=inf @ 1e-08)
# dim=40, F 4 -> None  (ERT=inf @ 1e-08)
# dim=40, F 5 -> None  (ERT=inf @ 1e-08)
# dim=40, F 6 -> None  (ERT=inf @ 1e-08)
# dim=40, F 7 -> None  (ERT=inf @ 1e-08)
# dim=40, F 8 -> None  (ERT=inf @ 1e-08)
# dim=40, F 9 -> None  (ERT=inf @ 1e-08)
# dim=40, F10 -> None  (ERT=inf @ 1e-08)
# dim=40, F11 -> None  (ERT=inf @ 1e-08)
# dim=40, F12 -> None  (ERT=inf @ 1e-08)
# dim=40, F13 -> None  (ERT=inf @ 1e-08)
# dim=40, F14 -> None  (ERT=inf @ 1e-08)
# dim=40, F15 -> None  (ERT=inf @ 1e-08)
# dim=40, F16 -> None  (ERT=inf @ 1e-08)
# dim=40, F17 -> None  (ERT=inf @ 1e-08)
# dim=40, F18 -> None  (ERT=inf @ 1e-08)
# dim=40, F19 -> None  (ERT=inf @ 1e-08)
# dim=40, F20 -> None  (ERT=inf @ 1e-08)
# dim=40, F21 -> None  (ERT=inf @ 1e-08)
# dim=40, F22 -> None  (ERT=inf @ 1e-08)
# dim=40, F23 -> None  (ERT=inf @ 1e-08)
# dim=40, F24 -> None  (ERT=inf @ 1e-08)
# dim=40, F25 -> None  (ERT=inf @ 1e-08)
# dim=40, F26 -> None  (ERT=inf @ 1e-08)
# dim=40, F27 -> None  (ERT=inf @ 1e-08)
# dim=40, F28 -> None  (ERT=inf @ 1e-08)
# dim=40, F29 -> None  (ERT=inf @ 1e-08)
# dim=40, F30 -> None  (ERT=inf @ 1e-08)
# dim=40, F31 -> None  (ERT=inf @ 1e-08)
# dim=40, F32 -> None  (ERT=inf @ 1e-08)
# dim=40, F33 -> None  (ERT=inf @ 1e-08)
# dim=40, F34 -> None  (ERT=inf @ 1e-08)
# dim=40, F35 -> None  (ERT=inf @ 1e-08)
# dim=40, F36 -> None  (ERT=inf @ 1e-08)
# dim=40, F37 -> None  (ERT=inf @ 1e-08)
# dim=40, F38 -> None  (ERT=inf @ 1e-08)
# dim=40, F39 -> None  (ERT=inf @ 1e-08)
# dim=40, F40 -> None  (ERT=inf @ 1e-08)
# dim=40, F41 -> None  (ERT=inf @ 1e-08)
# dim=40, F42 -> None  (ERT=inf @ 1e-08)
# dim=40, F43 -> None  (ERT=inf @ 1e-08)
# dim=40, F44 -> None  (ERT=inf @ 1e-08)
# dim=40, F45 -> None  (ERT=inf @ 1e-08)
# dim=40, F46 -> None  (ERT=inf @ 1e-08)
# dim=40, F47 -> None  (ERT=inf @ 1e-08)
# dim=40, F48 -> None  (ERT=inf @ 1e-08)
# dim=40, F49 -> None  (ERT=inf @ 1e-08)
# dim=40, F50 -> None  (ERT=inf @ 1e-08)
# dim=40, F51 -> None  (ERT=inf @ 1e-08)
# dim=40, F52 -> None  (ERT=inf @ 1e-08)
# dim=40, F53 -> None  (ERT=inf @ 1e-08)
# dim=40, F54 -> None  (ERT=inf @ 1e-08)
# dim=40, F55 -> None  (ERT=inf @ 1e-08)

# %% [markdown]
# ### Building a counter to count the number of times an algo appears in the above code

# %%
from collections import Counter, defaultdict

# %%
# Build a frequency counter: how many (dim,fid) each algo wins
win_counter = Counter(
    alg for (alg, ert) in best_by_df.values()
    if alg is not None and np.isfinite(ert)
)

# If you want a plain dict:
wins_dict = dict(win_counter)

# (Optional) pretty print, most wins first
for alg, count in win_counter.most_common():
    print(f"{alg}: {count}")
# Out:
# UP-MO-CMA-ES_Krause_bbob-biobj: 47
# HMO-CMA-ES_Loshchilov_bbob-biobj: 29
# RM-MEDA_Auger_bbob-biobj: 3

# %% [markdown]
# ### Deciding what is the best algo depending on the dimension.
#
# For each dimension, We will determine which is the best algo ( still working with a target precision of e 10-08 ). We will go through all the different functions and decide which one is the best (in the sense appears the most).

# %%
"""
Given best_by_df: {(dim, fid): (alg, ert)},
return {dim: algo_with_most_(fid)_wins_in_that_dim}.
Tie-break: lower total ERT across that dim, then alphabetical.
    """
wins = defaultdict(Counter)                    # dim -> Counter({alg: count})
ert_sums = defaultdict(lambda: defaultdict(float))  # dim -> {alg: total_ert}

for (dim, fid), (alg, ert) in best_by_df.items():
    if alg is None or not np.isfinite(ert):
        continue
    wins[dim][alg] += 1
    ert_sums[dim][alg] += float(ert)

result = {}
for dim, counter in wins.items():
    max_wins = max(counter.values())
    candidates = [a for a, c in counter.items() if c == max_wins]
    best = min(candidates, key=lambda a: (ert_sums[dim][a], a))  # tie-breaks
    result[dim] = best
result
# Out:
# {2: 'UP-MO-CMA-ES_Krause_bbob-biobj',
#  3: 'HMO-CMA-ES_Loshchilov_bbob-biobj',
#  5: 'UP-MO-CMA-ES_Krause_bbob-biobj',
#  10: 'UP-MO-CMA-ES_Krause_bbob-biobj',
#  20: 'UP-MO-CMA-ES_Krause_bbob-biobj'}

# %%
import numpy as np
import pandas as pd

# Make sure 'dd' already exists
# (if not, run: dsl = cocopp.load('path/to/your/ppdata'); dd = dsl.dictByDimFunc())

targets = [1e-1, 1e-2, 1e-3, 1e-5, 1e-8]
rows = []  # reset before starting the full loop

for dim in sorted(dd.keys()):                      # e.g. [2, 3, 5, 10, 20, 40]
    for fid in sorted(dd[dim].keys()):
        for t in targets:
            algo_erts = []
            for ds in dd[dim][fid]:                # each algorithm
                ert = float(ds.detERT([t])[0])
                algo_erts.append((ds.algId, ert))
            
            finite = [(a, e) for (a, e) in algo_erts if np.isfinite(e)]

            if finite:
                best_alg, best_ert = min(finite, key=lambda x: x[1])
            else:
                best_alg, best_ert = None, np.inf

            rows.append({
                "dimension": dim,
                "function_id": fid,
                "target": t,
                "best_algorithm": best_alg,
                "best_ERT": best_ert
            })

# Build DataFrame
df_best = pd.DataFrame(rows)
df_best = df_best.sort_values(by=["dimension", "function_id", "target"]).reset_index(drop=True)

# Confirm dimensions included
print("✅ Unique dimensions in table:", df_best["dimension"].unique())
print(df_best.head(15))
# Out:
# ✅ Unique dimensions in table: [ 2  3  5 10 20 40]
#     dimension  function_id        target                     best_algorithm  \
# 0           2            1  1.000000e-08                               None
# 1           2            1  1.000000e-05       SMS-EMOA-DE_Auger_bbob-biobj
# 2           2            1  1.000000e-03   HMO-CMA-ES_Loshchilov_bbob-biobj
# 3           2            1  1.000000e-02  MO-DIRECT-HV-Rank_Wong_bbob-biobj
# 4           2            1  1.000000e-01  MO-DIRECT-HV-Rank_Wong_bbob-biobj
# 5           2            2  1.000000e-08                               None
# 6           2            2  1.000000e-05     UP-MO-CMA-ES_Krause_bbob-biobj
# 7           2            2  1.000000e-03   HMO-CMA-ES_Loshchilov_bbob-biobj
# 8           2            2  1.000000e-02   HMO-CMA-ES_Loshchilov_bbob-biobj
# 9           2            2  1.000000e-01   HMO-CMA-ES_Loshchilov_bbob-biobj
# 10          2            3  1.000000e-08                               None
# 11          2            3  1.000000e-05     UP-MO-CMA-ES_Krause_bbob-biobj
# 12          2            3  1.000000e-03   HMO-CMA-ES_Loshchilov_bbob-biobj
# 13          2            3  1.000000e-02   HMO-CMA-ES_Loshchilov_bbob-biobj
# 14          2            3  1.000000e-01   HMO-CMA-ES_Loshchilov_bbob-biobj
#
#     best_ERT
# 0        inf
# 1    79968.4
# 2     1567.4
# 3      223.9
# 4       32.3
# 5        inf
# 6    97700.9
# 7      780.0
# 8      199.7
# 9       38.3
# 10       inf
# 11  191161.4
# 12    2689.6
# 13     316.6
# 14      61.8

# %% [markdown]
# #### Attention there are only the 15 first lines of the table that appear ! The table is very large !
#
# This is why I am making a file where all the data gets exported to.

# %%
import os
os.makedirs("results", exist_ok=True)

df_best.to_csv("results/bbob-biobj_2016.csv", index=False)
