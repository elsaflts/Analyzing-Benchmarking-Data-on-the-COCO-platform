# %% [markdown]
# # Data collection for the year 2019

# %%
import cocopp
dsl = cocopp.load("bbob/2019/*")
# Out:
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/Adaptive-Two-Mode_Bodner.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\Adaptive-Two-Mode_Bodner.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/BFGS-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\BFGS-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/CG-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\CG-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/COBYLA-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\COBYLA-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/DE-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\DE-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/GNN-CMA-ES_Faury.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\GNN-CMA-ES_Faury.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/IPOP-CMA-ES-2019_Faury.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\IPOP-CMA-ES-2019_Faury.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/L-BFGS-B-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\L-BFGS-B-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/Nelder-Mead-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\Nelder-Mead-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/Powell-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\Powell-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-0p5-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-0p5-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-0p5_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-0p5_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-1-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-1-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-10-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-10-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-10_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-10_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-1_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-1_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-2-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-2-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-20-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-20-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-20_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-20_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-2_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-2_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-3-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-3-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-3_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-3_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-4-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-4-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-5-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-5-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-6-initIn0_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-6-initIn0_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/RS-6_Brockhoff.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\RS-6_Brockhoff.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/SLSQP-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\SLSQP-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/TNC-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\TNC-scipy-2019_Varelas.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2019/adapt-Nelder-Mead-scipy-2019_Varelas.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\adapt-Nelder-Mead-scipy-2019_Varelas.tgz
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_Adaptive-Two-Mode_Bodner ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_BFGS-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_CG-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_COBYLA-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_DE-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_GNN-CMA-ES_Faury ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_IPOP-CMA-ES-2019_Faury ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_L-BFGS-B-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_Nelder-Mead-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_Powell-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-0p5-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-0p5_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-1-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-10-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-10_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-1_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-2-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-20-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-20_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-2_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-3-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-3_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-4-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-5-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-6-initIn0_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_RS-6_Brockhoff ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_SLSQP-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_TNC-scipy-2019_Varelas ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2019\.extracted_adapt-Nelder-Mead-scipy-2019_Varelas ...
#   Data consistent according to consistency_check() in pproc.DataSet

# %%
import numpy as np

dd = dsl.dictByDimFunc()     # your grouped datasets
t = 1e-8                     # choose the target precision

best_by_df = {}              # (dim, fid) -> (best_alg, best_ert)

for dim in sorted(dd.keys()): 
    for fid in sorted(dd[dim].keys()):
        rows = []
        for ds in dd[dim][fid]:                 # each ds = one algorithm
            ert = float(ds.detERT([t])[0])      # ERT in #evals at target t
            rows.append((ds.algId, ert))  
        # ignore INF (not reached) when picking best
        finite = [(a, e) for (a, e) in rows if np.isfinite(e)] 
    
        if finite:
            best_alg, best_ert = min(finite, key=lambda x: x[1]) 
        else:
            best_alg, best_ert = None, np.inf
        best_by_df[(dim, fid)] = (best_alg, best_ert) 
        print(f"dim={dim:>2}, F{fid:>2} -> {best_alg}  (ERT={best_ert:.3g} @ {t})")
# Out:
# dim= 2, F 1 -> SLSQP-scipy-2019_Varelas  (ERT=7 @ 1e-08)
# dim= 2, F 2 -> SLSQP-scipy-2019_Varelas  (ERT=57.9 @ 1e-08)
# dim= 2, F 3 -> DE-scipy-2019_Varelas  (ERT=1.52e+03 @ 1e-08)
# dim= 2, F 4 -> Powell-scipy-2019_Varelas  (ERT=336 @ 1e-08)
# dim= 2, F 5 -> RS-20-initIn0_Brockhoff  (ERT=6 @ 1e-08)
# dim= 2, F 6 -> SLSQP-scipy-2019_Varelas  (ERT=293 @ 1e-08)
# dim= 2, F 7 -> GNN-CMA-ES_Faury  (ERT=271 @ 1e-08)
# dim= 2, F 8 -> L-BFGS-B-scipy-2019_Varelas  (ERT=117 @ 1e-08)
# dim= 2, F 9 -> SLSQP-scipy-2019_Varelas  (ERT=120 @ 1e-08)
# dim= 2, F10 -> adapt-Nelder-Mead-scipy-2019_Varelas  (ERT=129 @ 1e-08)
# dim= 2, F11 -> Nelder-Mead-scipy-2019_Varelas  (ERT=148 @ 1e-08)
# dim= 2, F12 -> adapt-Nelder-Mead-scipy-2019_Varelas  (ERT=1.11e+03 @ 1e-08)
# dim= 2, F13 -> IPOP-CMA-ES-2019_Faury  (ERT=594 @ 1e-08)
# dim= 2, F14 -> adapt-Nelder-Mead-scipy-2019_Varelas  (ERT=119 @ 1e-08)
# dim= 2, F15 -> GNN-CMA-ES_Faury  (ERT=2.28e+03 @ 1e-08)
# dim= 2, F16 -> GNN-CMA-ES_Faury  (ERT=833 @ 1e-08)
# dim= 2, F17 -> GNN-CMA-ES_Faury  (ERT=2.22e+03 @ 1e-08)
# dim= 2, F18 -> IPOP-CMA-ES-2019_Faury  (ERT=2.21e+03 @ 1e-08)
# dim= 2, F19 -> GNN-CMA-ES_Faury  (ERT=1.93e+03 @ 1e-08)
# dim= 2, F20 -> DE-scipy-2019_Varelas  (ERT=717 @ 1e-08)
# dim= 2, F21 -> adapt-Nelder-Mead-scipy-2019_Varelas  (ERT=471 @ 1e-08)
# dim= 2, F22 -> SLSQP-scipy-2019_Varelas  (ERT=447 @ 1e-08)
# dim= 2, F23 -> GNN-CMA-ES_Faury  (ERT=2.29e+03 @ 1e-08)
# dim= 2, F24 -> DE-scipy-2019_Varelas  (ERT=6.39e+04 @ 1e-08)
# dim= 3, F 1 -> SLSQP-scipy-2019_Varelas  (ERT=8 @ 1e-08)
# dim= 3, F 2 -> SLSQP-scipy-2019_Varelas  (ERT=107 @ 1e-08)
# dim= 3, F 3 -> Powell-scipy-2019_Varelas  (ERT=6.26e+03 @ 1e-08)
# dim= 3, F 4 -> Powell-scipy-2019_Varelas  (ERT=5.61e+03 @ 1e-08)
# dim= 3, F 5 -> RS-20-initIn0_Brockhoff  (ERT=14.5 @ 1e-08)
# dim= 3, F 6 -> L-BFGS-B-scipy-2019_Varelas  (ERT=753 @ 1e-08)
# dim= 3, F 7 -> IPOP-CMA-ES-2019_Faury  (ERT=486 @ 1e-08)
# dim= 3, F 8 -> L-BFGS-B-scipy-2019_Varelas  (ERT=182 @ 1e-08)
# dim= 3, F 9 -> L-BFGS-B-scipy-2019_Varelas  (ERT=157 @ 1e-08)
# dim= 3, F10 -> Nelder-Mead-scipy-2019_Varelas  (ERT=491 @ 1e-08)
# dim= 3, F11 -> Nelder-Mead-scipy-2019_Varelas  (ERT=571 @ 1e-08)
# dim= 3, F12 -> Powell-scipy-2019_Varelas  (ERT=3.66e+03 @ 1e-08)
# dim= 3, F13 -> IPOP-CMA-ES-2019_Faury  (ERT=1.03e+03 @ 1e-08)
# dim= 3, F14 -> Nelder-Mead-scipy-2019_Varelas  (ERT=331 @ 1e-08)
# dim= 3, F15 -> GNN-CMA-ES_Faury  (ERT=8e+03 @ 1e-08)
# dim= 3, F16 -> GNN-CMA-ES_Faury  (ERT=1.98e+03 @ 1e-08)
# dim= 3, F17 -> GNN-CMA-ES_Faury  (ERT=3.43e+03 @ 1e-08)
# dim= 3, F18 -> GNN-CMA-ES_Faury  (ERT=3.77e+03 @ 1e-08)
# dim= 3, F19 -> GNN-CMA-ES_Faury  (ERT=2.23e+04 @ 1e-08)
# dim= 3, F20 -> DE-scipy-2019_Varelas  (ERT=2.6e+03 @ 1e-08)
# dim= 3, F21 -> adapt-Nelder-Mead-scipy-2019_Varelas  (ERT=1.65e+03 @ 1e-08)
# dim= 3, F22 -> SLSQP-scipy-2019_Varelas  (ERT=772 @ 1e-08)
# dim= 3, F23 -> GNN-CMA-ES_Faury  (ERT=6.37e+03 @ 1e-08)
# dim= 3, F24 -> DE-scipy-2019_Varelas  (ERT=1.33e+06 @ 1e-08)
# dim= 5, F 1 -> SLSQP-scipy-2019_Varelas  (ERT=10 @ 1e-08)
# dim= 5, F 2 -> Powell-scipy-2019_Varelas  (ERT=195 @ 1e-08)
# dim= 5, F 3 -> Adaptive-Two-Mode_Bodner  (ERT=5.07e+04 @ 1e-08)
# dim= 5, F 4 -> Powell-scipy-2019_Varelas  (ERT=4.9e+04 @ 1e-08)
# dim= 5, F 5 -> L-BFGS-B-scipy-2019_Varelas  (ERT=27.6 @ 1e-08)
# dim= 5, F 6 -> IPOP-CMA-ES-2019_Faury  (ERT=1.73e+03 @ 1e-08)
# dim= 5, F 7 -> IPOP-CMA-ES-2019_Faury  (ERT=1.24e+03 @ 1e-08)
# dim= 5, F 8 -> L-BFGS-B-scipy-2019_Varelas  (ERT=347 @ 1e-08)
# dim= 5, F 9 -> L-BFGS-B-scipy-2019_Varelas  (ERT=322 @ 1e-08)
# dim= 5, F10 -> IPOP-CMA-ES-2019_Faury  (ERT=1.49e+03 @ 1e-08)
# dim= 5, F11 -> IPOP-CMA-ES-2019_Faury  (ERT=1.28e+03 @ 1e-08)
# dim= 5, F12 -> IPOP-CMA-ES-2019_Faury  (ERT=4.01e+03 @ 1e-08)
# dim= 5, F13 -> IPOP-CMA-ES-2019_Faury  (ERT=2.43e+03 @ 1e-08)
# dim= 5, F14 -> adapt-Nelder-Mead-scipy-2019_Varelas  (ERT=885 @ 1e-08)
# dim= 5, F15 -> IPOP-CMA-ES-2019_Faury  (ERT=1.98e+04 @ 1e-08)
# dim= 5, F16 -> GNN-CMA-ES_Faury  (ERT=7.83e+03 @ 1e-08)
# dim= 5, F17 -> IPOP-CMA-ES-2019_Faury  (ERT=8.97e+03 @ 1e-08)
# dim= 5, F18 -> IPOP-CMA-ES-2019_Faury  (ERT=1.08e+04 @ 1e-08)
# dim= 5, F19 -> IPOP-CMA-ES-2019_Faury  (ERT=2.24e+05 @ 1e-08)
# dim= 5, F20 -> DE-scipy-2019_Varelas  (ERT=5.78e+04 @ 1e-08)
# dim= 5, F21 -> SLSQP-scipy-2019_Varelas  (ERT=7.57e+03 @ 1e-08)
# dim= 5, F22 -> Powell-scipy-2019_Varelas  (ERT=5.93e+03 @ 1e-08)
# dim= 5, F23 -> GNN-CMA-ES_Faury  (ERT=3.63e+04 @ 1e-08)
# dim= 5, F24 -> None  (ERT=inf @ 1e-08)
# dim=10, F 1 -> SLSQP-scipy-2019_Varelas  (ERT=15 @ 1e-08)
# dim=10, F 2 -> Powell-scipy-2019_Varelas  (ERT=412 @ 1e-08)
# dim=10, F 3 -> Adaptive-Two-Mode_Bodner  (ERT=2.05e+05 @ 1e-08)
# dim=10, F 4 -> Adaptive-Two-Mode_Bodner  (ERT=3.49e+05 @ 1e-08)
# dim=10, F 5 -> SLSQP-scipy-2019_Varelas  (ERT=49.2 @ 1e-08)
# dim=10, F 6 -> IPOP-CMA-ES-2019_Faury  (ERT=3.99e+03 @ 1e-08)
# dim=10, F 7 -> IPOP-CMA-ES-2019_Faury  (ERT=3.76e+03 @ 1e-08)
# dim=10, F 8 -> L-BFGS-B-scipy-2019_Varelas  (ERT=1.03e+03 @ 1e-08)
# dim=10, F 9 -> L-BFGS-B-scipy-2019_Varelas  (ERT=1.13e+03 @ 1e-08)
# dim=10, F10 -> IPOP-CMA-ES-2019_Faury  (ERT=4.16e+03 @ 1e-08)
# dim=10, F11 -> IPOP-CMA-ES-2019_Faury  (ERT=3.14e+03 @ 1e-08)
# dim=10, F12 -> IPOP-CMA-ES-2019_Faury  (ERT=1.04e+04 @ 1e-08)
# dim=10, F13 -> IPOP-CMA-ES-2019_Faury  (ERT=7.78e+03 @ 1e-08)
# dim=10, F14 -> IPOP-CMA-ES-2019_Faury  (ERT=3.77e+03 @ 1e-08)
# dim=10, F15 -> IPOP-CMA-ES-2019_Faury  (ERT=8.37e+04 @ 1e-08)
# dim=10, F16 -> IPOP-CMA-ES-2019_Faury  (ERT=3.94e+04 @ 1e-08)
# dim=10, F17 -> IPOP-CMA-ES-2019_Faury  (ERT=2.75e+04 @ 1e-08)
# dim=10, F18 -> IPOP-CMA-ES-2019_Faury  (ERT=3.85e+04 @ 1e-08)
# dim=10, F19 -> None  (ERT=inf @ 1e-08)
# dim=10, F20 -> DE-scipy-2019_Varelas  (ERT=4.29e+06 @ 1e-08)
# dim=10, F21 -> SLSQP-scipy-2019_Varelas  (ERT=2.79e+04 @ 1e-08)
# dim=10, F22 -> COBYLA-scipy-2019_Varelas  (ERT=4.1e+04 @ 1e-08)
# dim=10, F23 -> GNN-CMA-ES_Faury  (ERT=4.6e+05 @ 1e-08)
# dim=10, F24 -> None  (ERT=inf @ 1e-08)
# dim=20, F 1 -> SLSQP-scipy-2019_Varelas  (ERT=25 @ 1e-08)
# dim=20, F 2 -> Powell-scipy-2019_Varelas  (ERT=867 @ 1e-08)
# dim=20, F 3 -> Adaptive-Two-Mode_Bodner  (ERT=1.03e+06 @ 1e-08)
# dim=20, F 4 -> Adaptive-Two-Mode_Bodner  (ERT=2.32e+06 @ 1e-08)
# dim=20, F 5 -> SLSQP-scipy-2019_Varelas  (ERT=94.4 @ 1e-08)
# dim=20, F 6 -> L-BFGS-B-scipy-2019_Varelas  (ERT=3.51e+04 @ 1e-08)
# dim=20, F 7 -> None  (ERT=inf @ 1e-08)
# dim=20, F 8 -> L-BFGS-B-scipy-2019_Varelas  (ERT=3.12e+03 @ 1e-08)
# dim=20, F 9 -> L-BFGS-B-scipy-2019_Varelas  (ERT=2.98e+03 @ 1e-08)
# dim=20, F10 -> Powell-scipy-2019_Varelas  (ERT=1.08e+05 @ 1e-08)
# dim=20, F11 -> Powell-scipy-2019_Varelas  (ERT=1.32e+05 @ 1e-08)
# dim=20, F12 -> Powell-scipy-2019_Varelas  (ERT=2.72e+04 @ 1e-08)
# dim=20, F13 -> None  (ERT=inf @ 1e-08)
# dim=20, F14 -> Powell-scipy-2019_Varelas  (ERT=9.67e+04 @ 1e-08)
# dim=20, F15 -> None  (ERT=inf @ 1e-08)
# dim=20, F16 -> None  (ERT=inf @ 1e-08)
# dim=20, F17 -> None  (ERT=inf @ 1e-08)
# dim=20, F18 -> None  (ERT=inf @ 1e-08)
# dim=20, F19 -> None  (ERT=inf @ 1e-08)
# dim=20, F20 -> None  (ERT=inf @ 1e-08)
# dim=20, F21 -> COBYLA-scipy-2019_Varelas  (ERT=2.15e+04 @ 1e-08)
# dim=20, F22 -> COBYLA-scipy-2019_Varelas  (ERT=1.12e+05 @ 1e-08)
# dim=20, F23 -> None  (ERT=inf @ 1e-08)
# dim=20, F24 -> None  (ERT=inf @ 1e-08)
# dim=40, F 1 -> SLSQP-scipy-2019_Varelas  (ERT=45 @ 1e-08)
# dim=40, F 2 -> Powell-scipy-2019_Varelas  (ERT=1.68e+03 @ 1e-08)
# dim=40, F 3 -> Adaptive-Two-Mode_Bodner  (ERT=4.43e+06 @ 1e-08)
# dim=40, F 4 -> Adaptive-Two-Mode_Bodner  (ERT=1.2e+08 @ 1e-08)
# dim=40, F 5 -> SLSQP-scipy-2019_Varelas  (ERT=206 @ 1e-08)
# dim=40, F 6 -> L-BFGS-B-scipy-2019_Varelas  (ERT=1.01e+05 @ 1e-08)
# dim=40, F 7 -> None  (ERT=inf @ 1e-08)
# dim=40, F 8 -> L-BFGS-B-scipy-2019_Varelas  (ERT=1.26e+04 @ 1e-08)
# dim=40, F 9 -> L-BFGS-B-scipy-2019_Varelas  (ERT=1.11e+04 @ 1e-08)
# dim=40, F10 -> None  (ERT=inf @ 1e-08)
# dim=40, F11 -> Adaptive-Two-Mode_Bodner  (ERT=3.78e+06 @ 1e-08)
# dim=40, F12 -> Powell-scipy-2019_Varelas  (ERT=4.64e+04 @ 1e-08)
# dim=40, F13 -> None  (ERT=inf @ 1e-08)
# dim=40, F14 -> Powell-scipy-2019_Varelas  (ERT=6e+07 @ 1e-08)
# dim=40, F15 -> None  (ERT=inf @ 1e-08)
# dim=40, F16 -> None  (ERT=inf @ 1e-08)
# dim=40, F17 -> None  (ERT=inf @ 1e-08)
# dim=40, F18 -> None  (ERT=inf @ 1e-08)
# dim=40, F19 -> None  (ERT=inf @ 1e-08)
# dim=40, F20 -> None  (ERT=inf @ 1e-08)
# dim=40, F21 -> COBYLA-scipy-2019_Varelas  (ERT=7.86e+04 @ 1e-08)
# dim=40, F22 -> COBYLA-scipy-2019_Varelas  (ERT=3.34e+06 @ 1e-08)
# dim=40, F23 -> None  (ERT=inf @ 1e-08)
# dim=40, F24 -> None  (ERT=inf @ 1e-08)

# %%
from collections import Counter, defaultdict

# %%
# Build a frequency counter: how many (dim,fid) each algo wins
win_counter = Counter(
    alg for (alg, ert) in best_by_df.values()
    if alg is not None and np.isfinite(ert)
)

# If you want a plain dict:
wins_dict = dict(win_counter)

# (Optional) pretty print, most wins first
for alg, count in win_counter.most_common():
    print(f"{alg}: {count}")
# Out:
# IPOP-CMA-ES-2019_Faury: 25
# SLSQP-scipy-2019_Varelas: 17
# Powell-scipy-2019_Varelas: 16
# GNN-CMA-ES_Faury: 15
# L-BFGS-B-scipy-2019_Varelas: 15
# Adaptive-Two-Mode_Bodner: 8
# DE-scipy-2019_Varelas: 7
# adapt-Nelder-Mead-scipy-2019_Varelas: 6
# COBYLA-scipy-2019_Varelas: 5
# Nelder-Mead-scipy-2019_Varelas: 4
# RS-20-initIn0_Brockhoff: 2

# %%
"""
Given best_by_df: {(dim, fid): (alg, ert)},
return {dim: algo_with_most_(fid)_wins_in_that_dim}.
Tie-break: lower total ERT across that dim, then alphabetical.
    """
wins = defaultdict(Counter)                    # dim -> Counter({alg: count})
ert_sums = defaultdict(lambda: defaultdict(float))  # dim -> {alg: total_ert}

for (dim, fid), (alg, ert) in best_by_df.items():
    if alg is None or not np.isfinite(ert):
        continue
    wins[dim][alg] += 1
    ert_sums[dim][alg] += float(ert)

result = {}
for dim, counter in wins.items():
    max_wins = max(counter.values())
    candidates = [a for a, c in counter.items() if c == max_wins]
    best = min(candidates, key=lambda a: (ert_sums[dim][a], a))  # tie-breaks
    result[dim] = best
result
# Out:
# {2: 'GNN-CMA-ES_Faury',
#  3: 'GNN-CMA-ES_Faury',
#  5: 'IPOP-CMA-ES-2019_Faury',
#  10: 'IPOP-CMA-ES-2019_Faury',
#  20: 'Powell-scipy-2019_Varelas',
#  40: 'L-BFGS-B-scipy-2019_Varelas'}

# %%
import numpy as np
import pandas as pd

# Make sure 'dd' already exists
# (if not, run: dsl = cocopp.load('path/to/your/ppdata'); dd = dsl.dictByDimFunc())

targets = [1e-1, 1e-2, 1e-3, 1e-5, 1e-8]
rows = []  # reset before starting the full loop

for dim in sorted(dd.keys()):                      # e.g. [2, 3, 5, 10, 20, 40]
    for fid in sorted(dd[dim].keys()):
        for t in targets:
            algo_erts = []
            for ds in dd[dim][fid]:                # each algorithm
                ert = float(ds.detERT([t])[0])
                algo_erts.append((ds.algId, ert))
            
            finite = [(a, e) for (a, e) in algo_erts if np.isfinite(e)]

            if finite:
                best_alg, best_ert = min(finite, key=lambda x: x[1])
            else:
                best_alg, best_ert = None, np.inf

            rows.append({
                "dimension": dim,
                "function_id": fid,
                "target": t,
                "best_algorithm": best_alg,
                "best_ERT": best_ert
            })

# Build DataFrame
df_best = pd.DataFrame(rows)
df_best = df_best.sort_values(by=["dimension", "function_id", "target"]).reset_index(drop=True)

# Confirm dimensions included
print("✅ Unique dimensions in table:", df_best["dimension"].unique())
print(df_best.head(15))
# Out:
# ✅ Unique dimensions in table: [ 2  3  5 10 20 40]
#     dimension  function_id        target            best_algorithm  \
# 0           2            1  1.000000e-08  SLSQP-scipy-2019_Varelas
# 1           2            1  1.000000e-05  SLSQP-scipy-2019_Varelas
# 2           2            1  1.000000e-03  SLSQP-scipy-2019_Varelas
# 3           2            1  1.000000e-02  SLSQP-scipy-2019_Varelas
# 4           2            1  1.000000e-01  SLSQP-scipy-2019_Varelas
# 5           2            2  1.000000e-08  SLSQP-scipy-2019_Varelas
# 6           2            2  1.000000e-05  SLSQP-scipy-2019_Varelas
# 7           2            2  1.000000e-03  SLSQP-scipy-2019_Varelas
# 8           2            2  1.000000e-02  SLSQP-scipy-2019_Varelas
# 9           2            2  1.000000e-01  SLSQP-scipy-2019_Varelas
# 10          2            3  1.000000e-08     DE-scipy-2019_Varelas
# 11          2            3  1.000000e-05     DE-scipy-2019_Varelas
# 12          2            3  1.000000e-03     DE-scipy-2019_Varelas
# 13          2            3  1.000000e-02     DE-scipy-2019_Varelas
# 14          2            3  1.000000e-01     DE-scipy-2019_Varelas
#
#        best_ERT
# 0      7.000000
# 1      7.000000
# 2      7.000000
# 3      7.000000
# 4      7.000000
# 5     57.933333
# 6     47.533333
# 7     40.733333
# 8     36.133333
# 9     32.600000
# 10  1522.600000
# 11   743.866667
# 12   727.266667
# 13   684.333333
# 14   628.733333

# %%
import os
os.makedirs("results", exist_ok=True)

df_best.to_csv("results/best_algos_2019.csv", index=False)
