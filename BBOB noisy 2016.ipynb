# %% [markdown]
# # Starting to analyze the data of 2016
#
# We will now analyze the Biobj part of the data. This is a different class
#
#
# The core of this algo is to loop over every dimension possible and inside loop over all the different type of functions,  print the name of the function, its associated ERT at the time where it reaches the smallest target precision.

# %%
import cocopp
dsl = cocopp.load("bbob-noisy/2016/*")
# Out:
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-noisy/2016/PSAaLmC-CMA-ES_Nishida_bbob-noisy.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\PSAaLmC-CMA-ES_Nishida_bbob-noisy.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-noisy/2016/PSAaLmD-CMA-ES_Nishida_bbob-noisy.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\PSAaLmD-CMA-ES_Nishida_bbob-noisy.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-noisy/2016/PSAaSmC-CMA-ES_Nishida_bbob-noisy.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\PSAaSmC-CMA-ES_Nishida_bbob-noisy.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob-noisy/2016/PSAaSmD-CMA-ES_Nishida_bbob-noisy.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\PSAaSmD-CMA-ES_Nishida_bbob-noisy.tgz
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\.extracted_PSAaLmC-CMA-ES_Nishida_bbob-noisy ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\.extracted_PSAaLmD-CMA-ES_Nishida_bbob-noisy ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\.extracted_PSAaSmC-CMA-ES_Nishida_bbob-noisy ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob-noisy\2016\.extracted_PSAaSmD-CMA-ES_Nishida_bbob-noisy ...
#   Data consistent according to consistency_check() in pproc.DataSet

# %% [markdown]
# ### Determine what is the best algo for a target precision of 1e-08,
#
# This code will be looping over each dimension and each type of function.

# %%
import numpy as np

dd = dsl.dictByDimFunc()     # your grouped datasets
t = 1e-8                     # choose the target precision

best_by_df = {}              # (dim, fid) -> (best_alg, best_ert)

for dim in sorted(dd.keys()): 
    for fid in sorted(dd[dim].keys()):
        rows = []
        for ds in dd[dim][fid]:                 # each ds = one algorithm
            ert = float(ds.detERT([t])[0])      # ERT in #evals at target t
            rows.append((ds.algId, ert))  
        # ignore INF (not reached) when picking best
        finite = [(a, e) for (a, e) in rows if np.isfinite(e)] 
    
        if finite:
            best_alg, best_ert = min(finite, key=lambda x: x[1]) 
        else:
            best_alg, best_ert = None, np.inf
        best_by_df[(dim, fid)] = (best_alg, best_ert) 
        print(f"dim={dim:>2}, F{fid:>2} -> {best_alg}  (ERT={best_ert:.3g} @ {t})")
# Out:
# dim= 2, F101 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=363 @ 1e-08)
# dim= 2, F102 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=342 @ 1e-08)
# dim= 2, F103 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=405 @ 1e-08)
# dim= 2, F104 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.87e+03 @ 1e-08)
# dim= 2, F105 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=5.39e+04 @ 1e-08)
# dim= 2, F106 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.53e+03 @ 1e-08)
# dim= 2, F107 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=560 @ 1e-08)
# dim= 2, F108 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.44e+04 @ 1e-08)
# dim= 2, F109 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=815 @ 1e-08)
# dim= 2, F110 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.45e+05 @ 1e-08)
# dim= 2, F111 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=4.36e+05 @ 1e-08)
# dim= 2, F112 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=6.76e+03 @ 1e-08)
# dim= 2, F113 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.53e+04 @ 1e-08)
# dim= 2, F114 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.62e+04 @ 1e-08)
# dim= 2, F115 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=427 @ 1e-08)
# dim= 2, F116 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.38e+03 @ 1e-08)
# dim= 2, F117 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=6.57e+04 @ 1e-08)
# dim= 2, F118 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.99e+03 @ 1e-08)
# dim= 2, F119 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.42e+03 @ 1e-08)
# dim= 2, F120 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.1e+05 @ 1e-08)
# dim= 2, F121 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.9e+03 @ 1e-08)
# dim= 2, F122 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=1e+04 @ 1e-08)
# dim= 2, F123 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.53e+06 @ 1e-08)
# dim= 2, F124 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1e+04 @ 1e-08)
# dim= 2, F125 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.75e+04 @ 1e-08)
# dim= 2, F126 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.21e+05 @ 1e-08)
# dim= 2, F127 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.36e+04 @ 1e-08)
# dim= 2, F128 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=5.23e+04 @ 1e-08)
# dim= 2, F129 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.41e+05 @ 1e-08)
# dim= 2, F130 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=3.51e+03 @ 1e-08)
# dim= 3, F101 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=779 @ 1e-08)
# dim= 3, F102 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=723 @ 1e-08)
# dim= 3, F103 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=774 @ 1e-08)
# dim= 3, F104 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=5.2e+04 @ 1e-08)
# dim= 3, F105 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=4.6e+05 @ 1e-08)
# dim= 3, F106 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=7.51e+03 @ 1e-08)
# dim= 3, F107 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.07e+03 @ 1e-08)
# dim= 3, F108 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=4.51e+04 @ 1e-08)
# dim= 3, F109 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.37e+03 @ 1e-08)
# dim= 3, F110 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.98e+06 @ 1e-08)
# dim= 3, F111 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.02e+06 @ 1e-08)
# dim= 3, F112 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=9.37e+04 @ 1e-08)
# dim= 3, F113 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.36e+03 @ 1e-08)
# dim= 3, F114 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.06e+04 @ 1e-08)
# dim= 3, F115 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.12e+03 @ 1e-08)
# dim= 3, F116 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=4.14e+03 @ 1e-08)
# dim= 3, F117 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=9.21e+04 @ 1e-08)
# dim= 3, F118 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.78e+03 @ 1e-08)
# dim= 3, F119 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=5.91e+03 @ 1e-08)
# dim= 3, F120 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.61e+05 @ 1e-08)
# dim= 3, F121 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=5.33e+03 @ 1e-08)
# dim= 3, F122 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.16e+04 @ 1e-08)
# dim= 3, F123 -> None  (ERT=inf @ 1e-08)
# dim= 3, F124 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.04e+04 @ 1e-08)
# dim= 3, F125 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=7.65e+04 @ 1e-08)
# dim= 3, F126 -> None  (ERT=inf @ 1e-08)
# dim= 3, F127 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.47e+05 @ 1e-08)
# dim= 3, F128 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.66e+05 @ 1e-08)
# dim= 3, F129 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.59e+05 @ 1e-08)
# dim= 3, F130 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.23e+04 @ 1e-08)
# dim= 5, F101 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.07e+03 @ 1e-08)
# dim= 5, F102 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.02e+03 @ 1e-08)
# dim= 5, F103 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.28e+03 @ 1e-08)
# dim= 5, F104 -> None  (ERT=inf @ 1e-08)
# dim= 5, F105 -> None  (ERT=inf @ 1e-08)
# dim= 5, F106 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=9.95e+05 @ 1e-08)
# dim= 5, F107 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=4.96e+03 @ 1e-08)
# dim= 5, F108 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.49e+05 @ 1e-08)
# dim= 5, F109 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=4.29e+03 @ 1e-08)
# dim= 5, F110 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=7.05e+06 @ 1e-08)
# dim= 5, F111 -> None  (ERT=inf @ 1e-08)
# dim= 5, F112 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.52e+06 @ 1e-08)
# dim= 5, F113 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=4.24e+03 @ 1e-08)
# dim= 5, F114 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=5.49e+04 @ 1e-08)
# dim= 5, F115 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.8e+03 @ 1e-08)
# dim= 5, F116 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=4.5e+04 @ 1e-08)
# dim= 5, F117 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.83e+05 @ 1e-08)
# dim= 5, F118 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=6.98e+03 @ 1e-08)
# dim= 5, F119 -> PSAaLmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.23e+04 @ 1e-08)
# dim= 5, F120 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.4e+05 @ 1e-08)
# dim= 5, F121 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=9.51e+03 @ 1e-08)
# dim= 5, F122 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.09e+05 @ 1e-08)
# dim= 5, F123 -> None  (ERT=inf @ 1e-08)
# dim= 5, F124 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.36e+04 @ 1e-08)
# dim= 5, F125 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=6.67e+05 @ 1e-08)
# dim= 5, F126 -> None  (ERT=inf @ 1e-08)
# dim= 5, F127 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.36e+05 @ 1e-08)
# dim= 5, F128 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=7.59e+05 @ 1e-08)
# dim= 5, F129 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.04e+06 @ 1e-08)
# dim= 5, F130 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=3.3e+04 @ 1e-08)
# dim=10, F101 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=9.73e+03 @ 1e-08)
# dim=10, F102 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=9.85e+03 @ 1e-08)
# dim=10, F103 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.09e+04 @ 1e-08)
# dim=10, F104 -> None  (ERT=inf @ 1e-08)
# dim=10, F105 -> None  (ERT=inf @ 1e-08)
# dim=10, F106 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.22e+07 @ 1e-08)
# dim=10, F107 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=4.55e+04 @ 1e-08)
# dim=10, F108 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=3.73e+06 @ 1e-08)
# dim=10, F109 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=2.38e+04 @ 1e-08)
# dim=10, F110 -> None  (ERT=inf @ 1e-08)
# dim=10, F111 -> None  (ERT=inf @ 1e-08)
# dim=10, F112 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.34e+07 @ 1e-08)
# dim=10, F113 -> PSAaLmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.95e+04 @ 1e-08)
# dim=10, F114 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.22e+05 @ 1e-08)
# dim=10, F115 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=7.62e+03 @ 1e-08)
# dim=10, F116 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=5.83e+04 @ 1e-08)
# dim=10, F117 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.5e+07 @ 1e-08)
# dim=10, F118 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.66e+04 @ 1e-08)
# dim=10, F119 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=7.15e+04 @ 1e-08)
# dim=10, F120 -> None  (ERT=inf @ 1e-08)
# dim=10, F121 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.12e+04 @ 1e-08)
# dim=10, F122 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=7.4e+05 @ 1e-08)
# dim=10, F123 -> None  (ERT=inf @ 1e-08)
# dim=10, F124 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=8.97e+04 @ 1e-08)
# dim=10, F125 -> None  (ERT=inf @ 1e-08)
# dim=10, F126 -> None  (ERT=inf @ 1e-08)
# dim=10, F127 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.7e+06 @ 1e-08)
# dim=10, F128 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.02e+06 @ 1e-08)
# dim=10, F129 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.09e+06 @ 1e-08)
# dim=10, F130 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=2.03e+05 @ 1e-08)
# dim=20, F101 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=4.78e+04 @ 1e-08)
# dim=20, F102 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=4.83e+04 @ 1e-08)
# dim=20, F103 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=5.72e+04 @ 1e-08)
# dim=20, F104 -> None  (ERT=inf @ 1e-08)
# dim=20, F105 -> None  (ERT=inf @ 1e-08)
# dim=20, F106 -> None  (ERT=inf @ 1e-08)
# dim=20, F107 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=5.36e+05 @ 1e-08)
# dim=20, F108 -> None  (ERT=inf @ 1e-08)
# dim=20, F109 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.42e+05 @ 1e-08)
# dim=20, F110 -> None  (ERT=inf @ 1e-08)
# dim=20, F111 -> None  (ERT=inf @ 1e-08)
# dim=20, F112 -> None  (ERT=inf @ 1e-08)
# dim=20, F113 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.76e+05 @ 1e-08)
# dim=20, F114 -> None  (ERT=inf @ 1e-08)
# dim=20, F115 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.17e+04 @ 1e-08)
# dim=20, F116 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=6.51e+05 @ 1e-08)
# dim=20, F117 -> None  (ERT=inf @ 1e-08)
# dim=20, F118 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.55e+05 @ 1e-08)
# dim=20, F119 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=8.41e+05 @ 1e-08)
# dim=20, F120 -> None  (ERT=inf @ 1e-08)
# dim=20, F121 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=1.89e+05 @ 1e-08)
# dim=20, F122 -> None  (ERT=inf @ 1e-08)
# dim=20, F123 -> None  (ERT=inf @ 1e-08)
# dim=20, F124 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=6.22e+05 @ 1e-08)
# dim=20, F125 -> None  (ERT=inf @ 1e-08)
# dim=20, F126 -> None  (ERT=inf @ 1e-08)
# dim=20, F127 -> None  (ERT=inf @ 1e-08)
# dim=20, F128 -> PSAaSmC-CMA-ES_Nishida_bbob-noisy  (ERT=3.37e+06 @ 1e-08)
# dim=20, F129 -> None  (ERT=inf @ 1e-08)
# dim=20, F130 -> PSAaSmD-CMA-ES_Nishida_bbob-noisy  (ERT=1.24e+06 @ 1e-08)

# %% [markdown]
# ### Building a counter to count the number of times an algo appears in the above code

# %%
from collections import Counter, defaultdict

# %%
# Build a frequency counter: how many (dim,fid) each algo wins
win_counter = Counter(
    alg for (alg, ert) in best_by_df.values()
    if alg is not None and np.isfinite(ert)
)

# If you want a plain dict:
wins_dict = dict(win_counter)

# (Optional) pretty print, most wins first
for alg, count in win_counter.most_common():
    print(f"{alg}: {count}")
# Out:
# PSAaSmC-CMA-ES_Nishida_bbob-noisy: 54
# PSAaSmD-CMA-ES_Nishida_bbob-noisy: 24
# PSAaLmC-CMA-ES_Nishida_bbob-noisy: 21
# PSAaLmD-CMA-ES_Nishida_bbob-noisy: 20

# %% [markdown]
# ### Deciding what is the best algo depending on the dimension.
#
# For each dimension, We will determine which is the best algo ( still working with a target precision of e 10-08 ). We will go through all the different functions and decide which one is the best (in the sense appears the most).

# %%
"""
Given best_by_df: {(dim, fid): (alg, ert)},
return {dim: algo_with_most_(fid)_wins_in_that_dim}.
Tie-break: lower total ERT across that dim, then alphabetical.
    """
wins = defaultdict(Counter)                    # dim -> Counter({alg: count})
ert_sums = defaultdict(lambda: defaultdict(float))  # dim -> {alg: total_ert}

for (dim, fid), (alg, ert) in best_by_df.items():
    if alg is None or not np.isfinite(ert):
        continue
    wins[dim][alg] += 1
    ert_sums[dim][alg] += float(ert)

result = {}
for dim, counter in wins.items():
    max_wins = max(counter.values())
    candidates = [a for a, c in counter.items() if c == max_wins]
    best = min(candidates, key=lambda a: (ert_sums[dim][a], a))  # tie-breaks
    result[dim] = best
result
# Out:
# {2: 'PSAaSmC-CMA-ES_Nishida_bbob-noisy',
#  3: 'PSAaLmC-CMA-ES_Nishida_bbob-noisy',
#  5: 'PSAaSmC-CMA-ES_Nishida_bbob-noisy',
#  10: 'PSAaSmC-CMA-ES_Nishida_bbob-noisy',
#  20: 'PSAaSmC-CMA-ES_Nishida_bbob-noisy'}

# %%
import numpy as np
import pandas as pd

# Make sure 'dd' already exists
# (if not, run: dsl = cocopp.load('path/to/your/ppdata'); dd = dsl.dictByDimFunc())

targets = [1e-1, 1e-2, 1e-3, 1e-5, 1e-8]
rows = []  # reset before starting the full loop

for dim in sorted(dd.keys()):                      # e.g. [2, 3, 5, 10, 20, 40]
    for fid in sorted(dd[dim].keys()):
        for t in targets:
            algo_erts = []
            for ds in dd[dim][fid]:                # each algorithm
                ert = float(ds.detERT([t])[0])
                algo_erts.append((ds.algId, ert))
            
            finite = [(a, e) for (a, e) in algo_erts if np.isfinite(e)]

            if finite:
                best_alg, best_ert = min(finite, key=lambda x: x[1])
            else:
                best_alg, best_ert = None, np.inf

            rows.append({
                "dimension": dim,
                "function_id": fid,
                "target": t,
                "best_algorithm": best_alg,
                "best_ERT": best_ert
            })

# Build DataFrame
df_best = pd.DataFrame(rows)
df_best = df_best.sort_values(by=["dimension", "function_id", "target"]).reset_index(drop=True)

# Confirm dimensions included
print("✅ Unique dimensions in table:", df_best["dimension"].unique())
print(df_best.head(15))
# Out:
# ✅ Unique dimensions in table: [ 2  3  5 10 20]
#     dimension  function_id        target                     best_algorithm  \
# 0           2          101  1.000000e-08  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 1           2          101  1.000000e-05  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 2           2          101  1.000000e-03  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 3           2          101  1.000000e-02  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 4           2          101  1.000000e-01  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 5           2          102  1.000000e-08  PSAaSmD-CMA-ES_Nishida_bbob-noisy
# 6           2          102  1.000000e-05  PSAaSmD-CMA-ES_Nishida_bbob-noisy
# 7           2          102  1.000000e-03  PSAaSmD-CMA-ES_Nishida_bbob-noisy
# 8           2          102  1.000000e-02  PSAaSmD-CMA-ES_Nishida_bbob-noisy
# 9           2          102  1.000000e-01  PSAaSmD-CMA-ES_Nishida_bbob-noisy
# 10          2          103  1.000000e-08  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 11          2          103  1.000000e-05  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 12          2          103  1.000000e-03  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 13          2          103  1.000000e-02  PSAaLmD-CMA-ES_Nishida_bbob-noisy
# 14          2          103  1.000000e-01  PSAaLmD-CMA-ES_Nishida_bbob-noisy
#
#       best_ERT
# 0   362.733333
# 1   217.533333
# 2   135.866667
# 3    85.666667
# 4    61.733333
# 5   341.733333
# 6   201.933333
# 7   119.266667
# 8    82.733333
# 9    58.200000
# 10  405.133333
# 11  250.600000
# 12  147.133333
# 13  101.466667
# 14   66.466667

# %% [markdown]
# #### Attention there are only the 15 first lines of the table that appear ! The table is very large !
#
# This is why I am making a file where all the data gets exported to.

# %%
import os
os.makedirs("results", exist_ok=True)

df_best.to_csv("results/bbob-noisy_2016.csv", index=False)
