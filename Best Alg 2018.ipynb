# %% [markdown]
# # Data collection for the year 2018

# %%
import cocopp
dsl = cocopp.load("bbob/2018/*")
# Out:
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BBDE-N_Vodopija.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BBDE-N_Vodopija.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BBDE-best_Vodopija.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BBDE-best_Vodopija.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BBDE-ttb_Vodopija.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BBDE-ttb_Vodopija.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BBDE_Vodopija.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BBDE_Vodopija.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BFGS-M-17_Blelly.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BFGS-M-17_Blelly.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BFGS-P-09_Blelly.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BFGS-P-09_Blelly.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BFGS-P-Instances_Blelly.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BFGS-P-Instances_Blelly.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BFGS-P-StPt_Blelly.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BFGS-P-StPt_Blelly.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/BFGS-P-range_Blelly.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\BFGS-P-range_Blelly.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/CMAES-APOP-Var1_Nguyen.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\CMAES-APOP-Var1_Nguyen.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/CMAES-APOP-Var2_Nguyen.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\CMAES-APOP-Var2_Nguyen.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/CMAES-APOP-Var3_Nguyen.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\CMAES-APOP-Var3_Nguyen.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/DE-best_Vodopija.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\DE-best_Vodopija.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/DE-rand_Vodopija.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\DE-rand_Vodopija.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/DE-ttb_Vodopija.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\DE-ttb_Vodopija.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/PSA-CMA-ES_Nishida.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\PSA-CMA-ES_Nishida.tgz
#   downloading https://numbbo.github.io/data-archive/data-archive/bbob/2018/PSA-CMA-ESwRS_Nishida.tgz to C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\PSA-CMA-ESwRS_Nishida.tgz
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BBDE-N_Vodopija ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BBDE-best_Vodopija ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BBDE-ttb_Vodopija ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BBDE_Vodopija ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BFGS-M-17_Blelly ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BFGS-P-09_Blelly ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BFGS-P-Instances_Blelly ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BFGS-P-StPt_Blelly ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_BFGS-P-range_Blelly ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_CMAES-APOP-Var1_Nguyen ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_CMAES-APOP-Var2_Nguyen ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_CMAES-APOP-Var3_Nguyen ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_DE-best_Vodopija ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_DE-rand_Vodopija ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_DE-ttb_Vodopija ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_PSA-CMA-ES_Nishida ...
#     archive extracted to folder C:\Users\elsaf\AppData\Local\cocopp\cocopp\Cache\das\da\bbob\2018\.extracted_PSA-CMA-ESwRS_Nishida ...
# C:\Users\elsaf\anaconda3\Lib\site-packages\cocopp\pproc.py:1098: UserWarning:   less than 15 instances in the set [1] (f22, 40D)
#   warnings.warn('  less than ' + str(expectedNumberOfInstances) +
# C:\Users\elsaf\anaconda3\Lib\site-packages\cocopp\pproc.py:1117: UserWarning: Some DataSet of CMAES-APOP-Var2_Nguyen was not consistent
#   warnings.warn('Some DataSet of {0} was not consistent'.format(self.algId))  # should rather be in the previous messages

# %%
import numpy as np

dd = dsl.dictByDimFunc()     # your grouped datasets
t = 1e-8                     # choose the target precision

best_by_df = {}              # (dim, fid) -> (best_alg, best_ert)

for dim in sorted(dd.keys()): 
    for fid in sorted(dd[dim].keys()):
        rows = []
        for ds in dd[dim][fid]:                 # each ds = one algorithm
            ert = float(ds.detERT([t])[0])      # ERT in #evals at target t
            rows.append((ds.algId, ert))  
        # ignore INF (not reached) when picking best
        finite = [(a, e) for (a, e) in rows if np.isfinite(e)] 
    
        if finite:
            best_alg, best_ert = min(finite, key=lambda x: x[1]) 
        else:
            best_alg, best_ert = None, np.inf
        best_by_df[(dim, fid)] = (best_alg, best_ert) 
        print(f"dim={dim:>2}, F{fid:>2} -> {best_alg}  (ERT={best_ert:.3g} @ {t})")
# Out:
# dim= 2, F 1 -> BFGS-M-17_Blelly  (ERT=8.2 @ 1e-08)
# dim= 2, F 2 -> BFGS-P-StPt_Blelly  (ERT=113 @ 1e-08)
# dim= 2, F 3 -> DE-best_Vodopija  (ERT=1.33e+03 @ 1e-08)
# dim= 2, F 4 -> DE-best_Vodopija  (ERT=2.15e+03 @ 1e-08)
# dim= 2, F 5 -> BFGS-M-17_Blelly  (ERT=12.6 @ 1e-08)
# dim= 2, F 6 -> BFGS-P-StPt_Blelly  (ERT=352 @ 1e-08)
# dim= 2, F 7 -> PSA-CMA-ES_Nishida  (ERT=287 @ 1e-08)
# dim= 2, F 8 -> BFGS-M-17_Blelly  (ERT=237 @ 1e-08)
# dim= 2, F 9 -> BFGS-P-StPt_Blelly  (ERT=95.6 @ 1e-08)
# dim= 2, F10 -> BFGS-P-StPt_Blelly  (ERT=86.8 @ 1e-08)
# dim= 2, F11 -> BFGS-P-StPt_Blelly  (ERT=139 @ 1e-08)
# dim= 2, F12 -> CMAES-APOP-Var2_Nguyen  (ERT=823 @ 1e-08)
# dim= 2, F13 -> CMAES-APOP-Var2_Nguyen  (ERT=883 @ 1e-08)
# dim= 2, F14 -> BFGS-M-17_Blelly  (ERT=602 @ 1e-08)
# dim= 2, F15 -> DE-ttb_Vodopija  (ERT=2.32e+03 @ 1e-08)
# dim= 2, F16 -> BBDE-best_Vodopija  (ERT=1.01e+03 @ 1e-08)
# dim= 2, F17 -> PSA-CMA-ES_Nishida  (ERT=1.4e+03 @ 1e-08)
# dim= 2, F18 -> BBDE-best_Vodopija  (ERT=1.95e+03 @ 1e-08)
# dim= 2, F19 -> BBDE-best_Vodopija  (ERT=2.38e+03 @ 1e-08)
# dim= 2, F20 -> BFGS-P-Instances_Blelly  (ERT=827 @ 1e-08)
# dim= 2, F21 -> BBDE-best_Vodopija  (ERT=390 @ 1e-08)
# dim= 2, F22 -> BBDE-best_Vodopija  (ERT=539 @ 1e-08)
# dim= 2, F23 -> DE-best_Vodopija  (ERT=9.24e+03 @ 1e-08)
# dim= 2, F24 -> DE-rand_Vodopija  (ERT=2.95e+04 @ 1e-08)
# dim= 3, F 1 -> BFGS-M-17_Blelly  (ERT=18.3 @ 1e-08)
# dim= 3, F 2 -> BFGS-P-StPt_Blelly  (ERT=153 @ 1e-08)
# dim= 3, F 3 -> DE-best_Vodopija  (ERT=3.65e+03 @ 1e-08)
# dim= 3, F 4 -> DE-best_Vodopija  (ERT=4.52e+03 @ 1e-08)
# dim= 3, F 5 -> BFGS-M-17_Blelly  (ERT=16.5 @ 1e-08)
# dim= 3, F 6 -> CMAES-APOP-Var2_Nguyen  (ERT=894 @ 1e-08)
# dim= 3, F 7 -> PSA-CMA-ES_Nishida  (ERT=541 @ 1e-08)
# dim= 3, F 8 -> BFGS-P-StPt_Blelly  (ERT=370 @ 1e-08)
# dim= 3, F 9 -> BFGS-P-StPt_Blelly  (ERT=136 @ 1e-08)
# dim= 3, F10 -> BFGS-P-range_Blelly  (ERT=227 @ 1e-08)
# dim= 3, F11 -> BFGS-P-Instances_Blelly  (ERT=189 @ 1e-08)
# dim= 3, F12 -> BFGS-P-Instances_Blelly  (ERT=2.18e+03 @ 1e-08)
# dim= 3, F13 -> CMAES-APOP-Var1_Nguyen  (ERT=1.62e+03 @ 1e-08)
# dim= 3, F14 -> CMAES-APOP-Var1_Nguyen  (ERT=1.24e+03 @ 1e-08)
# dim= 3, F15 -> PSA-CMA-ESwRS_Nishida  (ERT=7.18e+03 @ 1e-08)
# dim= 3, F16 -> BBDE-best_Vodopija  (ERT=2.93e+03 @ 1e-08)
# dim= 3, F17 -> PSA-CMA-ES_Nishida  (ERT=2.27e+03 @ 1e-08)
# dim= 3, F18 -> PSA-CMA-ES_Nishida  (ERT=3.08e+03 @ 1e-08)
# dim= 3, F19 -> DE-best_Vodopija  (ERT=1.37e+04 @ 1e-08)
# dim= 3, F20 -> BFGS-P-Instances_Blelly  (ERT=4.46e+03 @ 1e-08)
# dim= 3, F21 -> BBDE-best_Vodopija  (ERT=806 @ 1e-08)
# dim= 3, F22 -> BBDE-best_Vodopija  (ERT=1.92e+03 @ 1e-08)
# dim= 3, F23 -> DE-best_Vodopija  (ERT=4.59e+04 @ 1e-08)
# dim= 3, F24 -> BBDE-ttb_Vodopija  (ERT=1.48e+05 @ 1e-08)
# dim= 5, F 1 -> BFGS-M-17_Blelly  (ERT=20.6 @ 1e-08)
# dim= 5, F 2 -> BFGS-P-StPt_Blelly  (ERT=349 @ 1e-08)
# dim= 5, F 3 -> DE-best_Vodopija  (ERT=1.44e+04 @ 1e-08)
# dim= 5, F 4 -> DE-rand_Vodopija  (ERT=3.18e+04 @ 1e-08)
# dim= 5, F 5 -> BFGS-P-Instances_Blelly  (ERT=25.8 @ 1e-08)
# dim= 5, F 6 -> CMAES-APOP-Var3_Nguyen  (ERT=1.73e+03 @ 1e-08)
# dim= 5, F 7 -> PSA-CMA-ES_Nishida  (ERT=1.05e+03 @ 1e-08)
# dim= 5, F 8 -> BFGS-P-range_Blelly  (ERT=904 @ 1e-08)
# dim= 5, F 9 -> BFGS-P-StPt_Blelly  (ERT=212 @ 1e-08)
# dim= 5, F10 -> BFGS-P-StPt_Blelly  (ERT=436 @ 1e-08)
# dim= 5, F11 -> BFGS-P-Instances_Blelly  (ERT=1.28e+03 @ 1e-08)
# dim= 5, F12 -> BFGS-P-StPt_Blelly  (ERT=2.24e+03 @ 1e-08)
# dim= 5, F13 -> CMAES-APOP-Var1_Nguyen  (ERT=4.05e+03 @ 1e-08)
# dim= 5, F14 -> CMAES-APOP-Var1_Nguyen  (ERT=2.36e+03 @ 1e-08)
# dim= 5, F15 -> PSA-CMA-ES_Nishida  (ERT=9.36e+03 @ 1e-08)
# dim= 5, F16 -> PSA-CMA-ESwRS_Nishida  (ERT=1.95e+04 @ 1e-08)
# dim= 5, F17 -> PSA-CMA-ES_Nishida  (ERT=4.86e+03 @ 1e-08)
# dim= 5, F18 -> PSA-CMA-ES_Nishida  (ERT=6.27e+03 @ 1e-08)
# dim= 5, F19 -> CMAES-APOP-Var1_Nguyen  (ERT=4.7e+04 @ 1e-08)
# dim= 5, F20 -> DE-ttb_Vodopija  (ERT=2.81e+04 @ 1e-08)
# dim= 5, F21 -> BBDE-best_Vodopija  (ERT=9.14e+03 @ 1e-08)
# dim= 5, F22 -> BBDE-best_Vodopija  (ERT=8.84e+03 @ 1e-08)
# dim= 5, F23 -> DE-best_Vodopija  (ERT=3.47e+05 @ 1e-08)
# dim= 5, F24 -> CMAES-APOP-Var2_Nguyen  (ERT=1.45e+07 @ 1e-08)
# dim=10, F 1 -> BFGS-M-17_Blelly  (ERT=79.5 @ 1e-08)
# dim=10, F 2 -> BFGS-P-StPt_Blelly  (ERT=914 @ 1e-08)
# dim=10, F 3 -> DE-ttb_Vodopija  (ERT=2.14e+05 @ 1e-08)
# dim=10, F 4 -> DE-ttb_Vodopija  (ERT=4.25e+05 @ 1e-08)
# dim=10, F 5 -> BFGS-P-StPt_Blelly  (ERT=50 @ 1e-08)
# dim=10, F 6 -> CMAES-APOP-Var1_Nguyen  (ERT=4.19e+03 @ 1e-08)
# dim=10, F 7 -> PSA-CMA-ES_Nishida  (ERT=3.69e+03 @ 1e-08)
# dim=10, F 8 -> BFGS-P-StPt_Blelly  (ERT=2.28e+03 @ 1e-08)
# dim=10, F 9 -> BFGS-P-StPt_Blelly  (ERT=604 @ 1e-08)
# dim=10, F10 -> BFGS-P-StPt_Blelly  (ERT=1.11e+03 @ 1e-08)
# dim=10, F11 -> CMAES-APOP-Var1_Nguyen  (ERT=5.71e+03 @ 1e-08)
# dim=10, F12 -> BFGS-P-Instances_Blelly  (ERT=1.04e+04 @ 1e-08)
# dim=10, F13 -> PSA-CMA-ES_Nishida  (ERT=1.31e+04 @ 1e-08)
# dim=10, F14 -> CMAES-APOP-Var3_Nguyen  (ERT=6.74e+03 @ 1e-08)
# dim=10, F15 -> PSA-CMA-ES_Nishida  (ERT=3.08e+04 @ 1e-08)
# dim=10, F16 -> CMAES-APOP-Var1_Nguyen  (ERT=1.27e+05 @ 1e-08)
# dim=10, F17 -> PSA-CMA-ES_Nishida  (ERT=1.59e+04 @ 1e-08)
# dim=10, F18 -> PSA-CMA-ES_Nishida  (ERT=1.92e+04 @ 1e-08)
# dim=10, F19 -> CMAES-APOP-Var1_Nguyen  (ERT=3.58e+05 @ 1e-08)
# dim=10, F20 -> CMAES-APOP-Var1_Nguyen  (ERT=2.35e+05 @ 1e-08)
# dim=10, F21 -> CMAES-APOP-Var3_Nguyen  (ERT=3.85e+04 @ 1e-08)
# dim=10, F22 -> PSA-CMA-ESwRS_Nishida  (ERT=1.53e+05 @ 1e-08)
# dim=10, F23 -> None  (ERT=inf @ 1e-08)
# dim=10, F24 -> PSA-CMA-ESwRS_Nishida  (ERT=3.38e+07 @ 1e-08)
# dim=20, F 1 -> BFGS-M-17_Blelly  (ERT=554 @ 1e-08)
# dim=20, F 2 -> BFGS-P-Instances_Blelly  (ERT=3.01e+03 @ 1e-08)
# dim=20, F 3 -> None  (ERT=inf @ 1e-08)
# dim=20, F 4 -> None  (ERT=inf @ 1e-08)
# dim=20, F 5 -> BFGS-P-StPt_Blelly  (ERT=90 @ 1e-08)
# dim=20, F 6 -> CMAES-APOP-Var3_Nguyen  (ERT=1.06e+04 @ 1e-08)
# dim=20, F 7 -> PSA-CMA-ES_Nishida  (ERT=1.41e+04 @ 1e-08)
# dim=20, F 8 -> BFGS-P-Instances_Blelly  (ERT=7.97e+03 @ 1e-08)
# dim=20, F 9 -> BFGS-P-StPt_Blelly  (ERT=1.48e+03 @ 1e-08)
# dim=20, F10 -> BFGS-P-range_Blelly  (ERT=3.03e+03 @ 1e-08)
# dim=20, F11 -> CMAES-APOP-Var1_Nguyen  (ERT=1.54e+04 @ 1e-08)
# dim=20, F12 -> CMAES-APOP-Var1_Nguyen  (ERT=2.34e+04 @ 1e-08)
# dim=20, F13 -> PSA-CMA-ES_Nishida  (ERT=4.41e+04 @ 1e-08)
# dim=20, F14 -> CMAES-APOP-Var3_Nguyen  (ERT=2.26e+04 @ 1e-08)
# dim=20, F15 -> CMAES-APOP-Var3_Nguyen  (ERT=9.65e+04 @ 1e-08)
# dim=20, F16 -> CMAES-APOP-Var1_Nguyen  (ERT=6.12e+05 @ 1e-08)
# dim=20, F17 -> PSA-CMA-ES_Nishida  (ERT=5.82e+04 @ 1e-08)
# dim=20, F18 -> PSA-CMA-ES_Nishida  (ERT=7.77e+04 @ 1e-08)
# dim=20, F19 -> PSA-CMA-ESwRS_Nishida  (ERT=2.61e+06 @ 1e-08)
# dim=20, F20 -> CMAES-APOP-Var1_Nguyen  (ERT=2.95e+06 @ 1e-08)
# dim=20, F21 -> DE-ttb_Vodopija  (ERT=1.97e+05 @ 1e-08)
# dim=20, F22 -> BBDE-ttb_Vodopija  (ERT=1.76e+06 @ 1e-08)
# dim=20, F23 -> None  (ERT=inf @ 1e-08)
# dim=20, F24 -> PSA-CMA-ESwRS_Nishida  (ERT=2.48e+07 @ 1e-08)
# dim=40, F 1 -> CMAES-APOP-Var1_Nguyen  (ERT=5.11e+03 @ 1e-08)
# dim=40, F 2 -> BFGS-P-range_Blelly  (ERT=7.37e+03 @ 1e-08)
# dim=40, F 3 -> None  (ERT=inf @ 1e-08)
# dim=40, F 4 -> None  (ERT=inf @ 1e-08)
# dim=40, F 5 -> BFGS-P-StPt_Blelly  (ERT=170 @ 1e-08)
# dim=40, F 6 -> CMAES-APOP-Var2_Nguyen  (ERT=2.79e+04 @ 1e-08)
# dim=40, F 7 -> PSA-CMA-ES_Nishida  (ERT=6.65e+04 @ 1e-08)
# dim=40, F 8 -> BFGS-P-Instances_Blelly  (ERT=2.63e+04 @ 1e-08)
# dim=40, F 9 -> BFGS-P-StPt_Blelly  (ERT=4.01e+03 @ 1e-08)
# dim=40, F10 -> BFGS-P-09_Blelly  (ERT=8.14e+03 @ 1e-08)
# dim=40, F11 -> PSA-CMA-ESwRS_Nishida  (ERT=4.49e+04 @ 1e-08)
# dim=40, F12 -> BFGS-P-Instances_Blelly  (ERT=2.73e+04 @ 1e-08)
# dim=40, F13 -> PSA-CMA-ES_Nishida  (ERT=3.99e+05 @ 1e-08)
# dim=40, F14 -> PSA-CMA-ESwRS_Nishida  (ERT=8.29e+04 @ 1e-08)
# dim=40, F15 -> CMAES-APOP-Var3_Nguyen  (ERT=3.27e+05 @ 1e-08)
# dim=40, F16 -> PSA-CMA-ESwRS_Nishida  (ERT=2.31e+06 @ 1e-08)
# dim=40, F17 -> PSA-CMA-ES_Nishida  (ERT=2.39e+05 @ 1e-08)
# dim=40, F18 -> PSA-CMA-ESwRS_Nishida  (ERT=4.48e+05 @ 1e-08)
# dim=40, F19 -> PSA-CMA-ES_Nishida  (ERT=5.82e+06 @ 1e-08)
# dim=40, F20 -> None  (ERT=inf @ 1e-08)
# dim=40, F21 -> DE-ttb_Vodopija  (ERT=1.27e+06 @ 1e-08)
# dim=40, F22 -> PSA-CMA-ESwRS_Nishida  (ERT=2.72e+08 @ 1e-08)
# dim=40, F23 -> None  (ERT=inf @ 1e-08)
# dim=40, F24 -> PSA-CMA-ESwRS_Nishida  (ERT=5.93e+08 @ 1e-08)

# %%
from collections import Counter, defaultdict

# %%
# Build a frequency counter: how many (dim,fid) each algo wins
win_counter = Counter(
    alg for (alg, ert) in best_by_df.values()
    if alg is not None and np.isfinite(ert)
)

# If you want a plain dict:
wins_dict = dict(win_counter)

# (Optional) pretty print, most wins first
for alg, count in win_counter.most_common():
    print(f"{alg}: {count}")
# Out:
# PSA-CMA-ES_Nishida: 22
# BFGS-P-StPt_Blelly: 21
# CMAES-APOP-Var1_Nguyen: 15
# PSA-CMA-ESwRS_Nishida: 12
# BFGS-P-Instances_Blelly: 11
# BBDE-best_Vodopija: 10
# BFGS-M-17_Blelly: 9
# DE-best_Vodopija: 9
# CMAES-APOP-Var3_Nguyen: 7
# DE-ttb_Vodopija: 6
# CMAES-APOP-Var2_Nguyen: 5
# BFGS-P-range_Blelly: 4
# DE-rand_Vodopija: 2
# BBDE-ttb_Vodopija: 2
# BFGS-P-09_Blelly: 1

# %%
"""
Given best_by_df: {(dim, fid): (alg, ert)},
return {dim: algo_with_most_(fid)_wins_in_that_dim}.
Tie-break: lower total ERT across that dim, then alphabetical.
    """
wins = defaultdict(Counter)                    # dim -> Counter({alg: count})
ert_sums = defaultdict(lambda: defaultdict(float))  # dim -> {alg: total_ert}

for (dim, fid), (alg, ert) in best_by_df.items():
    if alg is None or not np.isfinite(ert):
        continue
    wins[dim][alg] += 1
    ert_sums[dim][alg] += float(ert)

result = {}
for dim, counter in wins.items():
    max_wins = max(counter.values())
    candidates = [a for a, c in counter.items() if c == max_wins]
    best = min(candidates, key=lambda a: (ert_sums[dim][a], a))  # tie-breaks
    result[dim] = best
result
# Out:
# {2: 'BFGS-P-StPt_Blelly',
#  3: 'DE-best_Vodopija',
#  5: 'BFGS-P-StPt_Blelly',
#  10: 'BFGS-P-StPt_Blelly',
#  20: 'PSA-CMA-ES_Nishida',
#  40: 'PSA-CMA-ESwRS_Nishida'}

# %%
import numpy as np
import pandas as pd

# Make sure 'dd' already exists
# (if not, run: dsl = cocopp.load('path/to/your/ppdata'); dd = dsl.dictByDimFunc())

targets = [1e-1, 1e-2, 1e-3, 1e-5, 1e-8]
rows = []  # reset before starting the full loop

for dim in sorted(dd.keys()):                      # e.g. [2, 3, 5, 10, 20, 40]
    for fid in sorted(dd[dim].keys()):
        for t in targets:
            algo_erts = []
            for ds in dd[dim][fid]:                # each algorithm
                ert = float(ds.detERT([t])[0])
                algo_erts.append((ds.algId, ert))
            
            finite = [(a, e) for (a, e) in algo_erts if np.isfinite(e)]

            if finite:
                best_alg, best_ert = min(finite, key=lambda x: x[1])
            else:
                best_alg, best_ert = None, np.inf

            rows.append({
                "dimension": dim,
                "function_id": fid,
                "target": t,
                "best_algorithm": best_alg,
                "best_ERT": best_ert
            })

# Build DataFrame
df_best = pd.DataFrame(rows)
df_best = df_best.sort_values(by=["dimension", "function_id", "target"]).reset_index(drop=True)

# Confirm dimensions included
print("✅ Unique dimensions in table:", df_best["dimension"].unique())
print(df_best.head(15))
# Out:
# ✅ Unique dimensions in table: [ 2  3  5 10 20 40]
#     dimension  function_id        target           best_algorithm     best_ERT
# 0           2            1  1.000000e-08         BFGS-M-17_Blelly     8.200000
# 1           2            1  1.000000e-05         BFGS-M-17_Blelly     7.000000
# 2           2            1  1.000000e-03         BFGS-M-17_Blelly     7.000000
# 3           2            1  1.000000e-02         BFGS-M-17_Blelly     7.000000
# 4           2            1  1.000000e-01         BFGS-M-17_Blelly     7.000000
# 5           2            2  1.000000e-08       BFGS-P-StPt_Blelly   113.200000
# 6           2            2  1.000000e-05       BFGS-P-StPt_Blelly    94.000000
# 7           2            2  1.000000e-03  BFGS-P-Instances_Blelly    86.200000
# 8           2            2  1.000000e-02  BFGS-P-Instances_Blelly    80.066667
# 9           2            2  1.000000e-01  BFGS-P-Instances_Blelly    75.800000
# 10          2            3  1.000000e-08         DE-best_Vodopija  1331.200000
# 11          2            3  1.000000e-05         DE-best_Vodopija  1081.066667
# 12          2            3  1.000000e-03         DE-best_Vodopija   924.733333
# 13          2            3  1.000000e-02         DE-best_Vodopija   832.600000
# 14          2            3  1.000000e-01         DE-best_Vodopija   737.866667

# %%
import os
os.makedirs("results", exist_ok=True)

df_best.to_csv("results/best_algos_2018.csv", index=False)
